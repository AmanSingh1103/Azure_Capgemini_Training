# %%
pip install azure-ai-projects azure-core
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.6/236.6 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.3/218.3 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.5/121.5 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# Step 1: Install required library
# !pip install --upgrade openai

# Step 2: Import modules
from google.colab import userdata
from openai import OpenAI

# Step 3: Load API key (saved as "kaif")
api_key = userdata.get("aaif")

# Step 4: Azure Foundry endpoint (with project path)
endpoint = "https://email-assistant-resource.services.ai.azure.com/api/projects/email-assistant"

# Step 5: Agent details
agent_name = "Customer-Support-Chatbot"
version = "1"
# Step 6: Create client
client = OpenAI(
    api_key=api_key,
    base_url=f"{endpoint}/openai/v1"
)

# Step 7: Take user input
user_input = input("Ask your Customer support chatbot: ")

# Step 8: Send request to agent
response = client.responses.create(
    input=user_input,
    extra_body={
        "agent_reference": {
            "name": agent_name,
            "version": version,
            "type": "agent_reference"
        }
    }
)

# Step 9: Print response
print("\n AI Generated Response:\n")
print(response.output_text)
# Out:
# ...
# Ask your Customer support chatbot: how can i contact support
#
#  AI Generated Response:
#
# To contact support, you'll need to clarify what kind of support or organization you're trying to reach (e.g., technical support for a specific service, customer service for a product, or other assistance). Here are some general steps:
#
# 1. **Check the Website**:
#    - Most companies have a "Help," "Support," or "Contact Us" section on their website. Look for this section, as it will often include phone numbers, email addresses, or live chat options.
#
# 2. **Social Media**:
#    - Many companies offer support via their social media accounts like Twitter or Facebook. You can check their official accounts or send them a direct message.
#
# 3. **Email or Call**:
#    - If you know the service or product you're seeking help for, look for an official support email or phone number on their website.
#
# 4. **Search Online**:
# ...
